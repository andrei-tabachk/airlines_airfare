# %%
# sqlite_demo.py

import sqlite3
import pandas as pd

from pathlib import Path

# use pandas to create dataframe based on csv data
df_airefare_decrease = pd.read_csv(f'Consumer_Airfare_Report__Table_4_-_City-Pair_Markets_With_A_Substantial_Decrease_In_Average_Fare.csv')
filtered_airefare_decrease = df_airefare_decrease[df_airefare_decrease['Year'] == 2017]
filtered_airefare_decrease
# Out:
#           tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 74    Table 4  2017        2           30423           33198
# 1682  Table 4  2017        1           30140           30423
# 1683  Table 4  2017        1           30189           31454
# 1684  Table 4  2017        1           30397           30466
# 1685  Table 4  2017        1           30397           30529
# ...       ...   ...      ...             ...             ...
# 1835  Table 4  2017        4           33192           33570
# 1836  Table 4  2017        4           33342           30693
# 1837  Table 4  2017        4           33495           34492
# 1838  Table 4  2017        4           33851           31454
# 1839  Table 4  2017        4           35412           31703
#
#                                city1                                 city2  \
# 74                        Austin, TX                       Kansas City, MO
# 1682                 Albuquerque, NM                            Austin, TX
# ...

# %%
filtered_airefare_decrease[['City','Coordinate_City1']] = filtered_airefare_decrease['Geocoded_City1'].str.split('/', expand=True, n=1)
# Out:
# C:\Users\k3net\AppData\Local\Temp\ipykernel_15368\302139385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_airefare_decrease[['City','Coordinate_City1']] = filtered_airefare_decrease['Geocoded_City1'].str.split('/', expand=True, n=1)
# C:\Users\k3net\AppData\Local\Temp\ipykernel_15368\302139385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
filtered_airefare_decrease[['City','Coordinate_City2']] = filtered_airefare_decrease['Geocoded_City2'].str.split('/', expand=True, n=1)
# Out:
# C:\Users\k3net\AppData\Local\Temp\ipykernel_15368\4082626458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_airefare_decrease[['City','Coordinate_City2']] = filtered_airefare_decrease['Geocoded_City2'].str.split('/', expand=True, n=1)
# C:\Users\k3net\AppData\Local\Temp\ipykernel_15368\4082626458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
filtered_airefare_decrease
#drop City-
# Out:
#           tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 74    Table 4  2017        2           30423           33198
# 1682  Table 4  2017        1           30140           30423
# 1683  Table 4  2017        1           30189           31454
# 1684  Table 4  2017        1           30397           30466
# 1685  Table 4  2017        1           30397           30529
# ...       ...   ...      ...             ...             ...
# 1835  Table 4  2017        4           33192           33570
# 1836  Table 4  2017        4           33342           30693
# 1837  Table 4  2017        4           33495           34492
# 1838  Table 4  2017        4           33851           31454
# 1839  Table 4  2017        4           35412           31703
#
#                                city1                                 city2  \
# 74                        Austin, TX                       Kansas City, MO
# 1682                 Albuquerque, NM                            Austin, TX
# ...

# %%
filtered_airefare_decrease.drop(columns=['City'])
# Out:
#           tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 74    Table 4  2017        2           30423           33198
# 1682  Table 4  2017        1           30140           30423
# 1683  Table 4  2017        1           30189           31454
# 1684  Table 4  2017        1           30397           30466
# 1685  Table 4  2017        1           30397           30529
# ...       ...   ...      ...             ...             ...
# 1835  Table 4  2017        4           33192           33570
# 1836  Table 4  2017        4           33342           30693
# 1837  Table 4  2017        4           33495           34492
# 1838  Table 4  2017        4           33851           31454
# 1839  Table 4  2017        4           35412           31703
#
#                                city1                                 city2  \
# 74                        Austin, TX                       Kansas City, MO
# 1682                 Albuquerque, NM                            Austin, TX
# ...
